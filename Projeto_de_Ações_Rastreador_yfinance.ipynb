# %% [markdown]
# <a href="https://colab.research.google.com/github/Fernanfds/Fernanfds/blob/main/Projeto_de_A%C3%A7%C3%B5es_Rastreador_yfinance.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install  yfinance
import yfinance as yf
import matplotlib.pyplot as plt

# %%
acoes = ['BBAS3.SA', 'PETR4.SA', 'VALE3.SA', 'CMIG4.SA']

# %%
dados_acoes = yf.download(acoes, start='2023-01-01', end='2024-06-01')
# Out:
# [*********************100%%**********************]  4 of 4 completed

# %%
dados_acoes['Close'].plot()
plt.xlabel('Data')
plt.ylabel('Preço de Fechamento')
plt.title('Rastreador de Ações')
plt.legend(acoes, fontsize=7)
plt.show()

# %%
dados_normalizados = dados_acoes['Close'] / dados_acoes['Close'].iloc[0]
dados_normalizados.plot()
plt.xlabel('Data')
plt.ylabel('Preço Normalizado')
plt.title('Rastreador de Ações')
plt.legend(acoes, fontsize=7)
plt.show()
