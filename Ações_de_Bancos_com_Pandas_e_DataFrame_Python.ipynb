# %% [markdown]
# <a href="https://colab.research.google.com/github/Fernanfds/Fernanfds/blob/main/A%C3%A7%C3%B5es_de_Bancos_com_Pandas_e_DataFrame_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
pd.DataFrame()
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
Ações = {

'Ticker' : ['BBAS3', 'ITUB4','BPAC11','BBDC4','SANB11'],
'P/L' : ['5,02%', '9,78%', '12,60%', '11,06%', '9,81%'],
'P/VP' : ['0,91', '1,87', '2,60', '0,88', '0,96'],
'ROE' : ['18,08%', '19,10%', '20,63%', '7,94%', '9,82%'],
'DY' : ['8,65%', '6,43%', '2,25%', '8,91%', '5,36%'],
'Margem_Liquida' : ['12,16%', '11,51%', '21,78%', '6,06%', '8,81%'],
'Valor_De_Mercado' : ['$162,30 B', '$336,23 B', '$162,77 B', '$153,13 B', '$112,86 B' ],

}

pd.DataFrame(Ações)
# Out:
#    Ticker     P/L  P/VP     ROE     DY Margem_Liquida Valor_De_Mercado
# 0   BBAS3   5,02%  0,91  18,08%  8,65%         12,16%        $162,30 B
# 1   ITUB4   9,78%  1,87  19,10%  6,43%         11,51%        $336,23 B
# 2  BPAC11  12,60%  2,60  20,63%  2,25%         21,78%        $162,77 B
# 3   BBDC4  11,06%  0,88   7,94%  8,91%          6,06%        $153,13 B
# 4  SANB11   9,81%  0,96   9,82%  5,36%          8,81%        $112,86 B

# %%
df.sort_values(by='P/VP')
# Out:
#    Ticker     P/L  P/VP     ROE     DY Margem_Liquida Valor_De_Mercado
# 3   BBDC4  11,06%  0,88   7,94%  8,91%          6,06%        $153,13 B
# 0   BBAS3   5,02%  0,91  18,08%  8,65%         12,16%        $162,30 B
# 4  SANB11   9,81%  0,96   9,82%  5,36%          8,81%        $112,86 B
# 1   ITUB4   9,78%  1,87  19,10%  6,43%         11,51%        $336,23 B
# 2  BPAC11  12,60%  2,60  20,63%  2,25%         21,78%        $162,77 B
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_26.groupby('Ticker').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_27.groupby('P/L').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# ...

# %%
df.sort_values(by='P/VP', ascending=False)
# Out:
#    Ticker     P/L  P/VP     ROE     DY Margem_Liquida Valor_De_Mercado
# 2  BPAC11  12,60%  2,60  20,63%  2,25%         21,78%        $162,77 B
# 1   ITUB4   9,78%  1,87  19,10%  6,43%         11,51%        $336,23 B
# 4  SANB11   9,81%  0,96   9,82%  5,36%          8,81%        $112,86 B
# 0   BBAS3   5,02%  0,91  18,08%  8,65%         12,16%        $162,30 B
# 3   BBDC4  11,06%  0,88   7,94%  8,91%          6,06%        $153,13 B
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_34.groupby('Ticker').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_35.groupby('P/L').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# ...

# %%
from matplotlib import pyplot as plt
import numpy as np
import pandas as pd
_df_8['index'].plot(kind='hist', bins=20, title='index')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
import matplotlib.pyplot as plt
from matplotlib import pyplot as plt
import numpy as np
import pandas as pd
Ações = ['BBAS3', 'ITUB4','BPAC11','BBDC4','SANB11']
DY = ['8,65%', '6,43%', '2,25%', '8,91%', '5,36%']
P_VP = ['0,91', '1,87', '2,60', '0,88', '0,96']

grafico.xlabel('DY')
grafico.ylabel('ticker')
grafico.scatter(DY,Ações)
grafico.scatter(P_VP,Ações)
grafico.show()

# %%
x = np.linspace(0, 2, 21)
plt.plot(x, x)
plt.plot(x, x**2)
plt.plot(x, x**3)
plt.show()
