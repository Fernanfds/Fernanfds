# %% [markdown]
# <a href="https://colab.research.google.com/github/Fernanfds/Fernanfds/blob/main/Exemplos_de_Graficos_Ibov.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import pandas_datareader.data as web

# !pip install yfinance --upgrade--no-cahe-dir
import yfinance as yf

# %%
ibov = web.get_data_yahoo('^BVSP')
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
ibov.head()
# Out:
#                  Open       High        Low      Close  Adj Close  Volume
# Date
# 1993-04-27  24.799999  25.400000  24.500000  24.500000  24.500000       0
# 1993-04-28  24.500000  24.600000  23.700001  24.299999  24.299999       0
# 1993-04-29  24.299999  24.799999  23.700001  23.700001  23.700001       0
# 1993-04-30  23.700001  24.200001  23.700001  24.100000  24.100000       0
# 1993-05-03  24.100000  24.400000  23.799999  24.100000  24.100000       0

# %%
ibov.tail()
# Out:
#                      Open           High           Low         Close  \
# Date
# 2024-03-19  126955.000000  128000.000000  126955.00000  127529.00000
# 2024-03-20  127534.000000  129210.000000  127349.00000  129125.00000
# 2024-03-21  129125.000000  129556.000000  128093.00000  128159.00000
# 2024-03-22  128159.000000  128159.000000  126879.00000  127027.00000
# 2024-03-25  127027.101562  127224.320312  126750.46875  126931.46875
#
#                Adj Close    Volume
# Date
# 2024-03-19  127529.00000  11184800
# 2024-03-20  129125.00000  10819300
# 2024-03-21  128159.00000   9570800
# 2024-03-22  127027.00000   9367800
# 2024-03-25  126931.46875         0

# %%
ibov["Close"].plot(figsize=(22,8), label="IBOV")
ibov["Close"].rolling(21).mean().plot(label="MM21")
ibov["Close"].rolling(200).mean().plot(label="MM200")
plt.legend()

# %%
ibov_fatiado = ibov[ibov.index.year == 2023]
ibov_fatiado["Close"].plot(figsize=(22,8), label="IBOV")
ibov_fatiado["Close"].rolling(21).mean().plot(label="MM21")
ibov_fatiado["Close"].rolling(200).mean().plot(label="MM200")
plt.legend()

# %%
ibov_fatiado = ibov[(ibov.index.year >= 2020) & (ibov.index.year <= 2023)]
ibov["Close"].plot(figsize=(22,8), label="IBOV")
ibov["Close"].rolling(21).mean().plot(label="MM21")
ibov["Close"].rolling(200).mean().plot(label="MM200")
plt.legend()

# %%
ibov = web.get_data_yahoo('VALE3.SA', start='2015-01-01', end='2024-01-30')
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
ibov.head()
# Out:
#                  Open       High        Low      Close  Adj Close   Volume
# Date
# 2015-01-02  21.700001  21.950001  21.059999  21.280001  12.060664  5658400
# 2015-01-05  20.760000  21.129999  20.510000  20.959999  11.879302  8603000
# 2015-01-06  21.070000  22.129999  21.070000  21.799999  12.355378  9879900
# 2015-01-07  22.320000  22.809999  21.969999  22.600000  12.808788  6130900
# 2015-01-08  22.770000  22.879999  22.110001  22.840000  12.944810  4667300

# %%
ibov["Close"].plot(figsize=(22,8), label="VALE3.SA")
ibov["Close"].rolling(21).mean().plot(label="MM21")
ibov["Close"].rolling(200).mean().plot(label="MM200")
plt.legend()
