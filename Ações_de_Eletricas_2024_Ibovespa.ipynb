# %% [markdown]
# <a href="https://colab.research.google.com/github/Fernanfds/Fernanfds/blob/main/A%C3%A7%C3%B5es_de_Eletricas_2024_Ibovespa.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Mercado de Ações Ibov 2024.
# ##### Setor: Elétrico

# %%
import pandas as pd
import numpy as np
pd.DataFrame()
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
Ações = {
    'Ticker' : ['ELET3', 'EQTL3', 'CPFE3', 'EGIE3', 'CMIG4', 'CPLE6'],
    'P/L' : ['21,07%', '18,33%', '7,08%', '8,65%', '5,57%', '13,37%'],
    'P/VP' : ['0,82', '1,78', '2,02', '3,42', '1,25', '1,25'],
    'ROE' : ['3,90%', '9,71%', '28,53%', '39,51%', '22,35%', '9,36%'],
    'DY' : ['1,00%', '1,29%', '10,61%', '5,09%', '11,81%', '3,65%'],
    'Margem_Liquida' : ['12,41%', '5,20%', '13,56%', '41,09%', '15,74%', '10,79%'],
    'Valor_De_Mercado' : ['$101,87 B', '$40,00 B', '$38,72 B', '$37,83 B', '$35,31 B', '$31,03 B' ],

}
df = pd.DataFrame(Ações)
df
# Out:
#   Ticker     P/L  P/VP     ROE      DY Margem_Liquida Valor_De_Mercado
# 0  ELET3  21,07%  0,82   3,90%   1,00%         12,41%        $101,87 B
# 1  EQTL3  18,33%  1,78   9,71%   1,29%          5,20%         $40,00 B
# 2  CPFE3   7,08%  2,02  28,53%  10,61%         13,56%         $38,72 B
# 3  EGIE3   8,65%  3,42  39,51%   5,09%         41,09%         $37,83 B
# 4  CMIG4   5,57%  1,25  22,35%  11,81%         15,74%         $35,31 B
# 5  CPLE6  13,37%  1,25   9,36%   3,65%         10,79%         $31,03 B

# %%
df.sort_values(by='P/VP')
# Out:
#   Ticker     P/L  P/VP     ROE      DY Margem_Liquida Valor_De_Mercado
# 0  ELET3  21,07%  0,82   3,90%   1,00%         12,41%        $101,87 B
# 4  CMIG4   5,57%  1,25  22,35%  11,81%         15,74%         $35,31 B
# 5  CPLE6  13,37%  1,25   9,36%   3,65%         10,79%         $31,03 B
# 1  EQTL3  18,33%  1,78   9,71%   1,29%          5,20%         $40,00 B
# 2  CPFE3   7,08%  2,02  28,53%  10,61%         13,56%         $38,72 B
# 3  EGIE3   8,65%  3,42  39,51%   5,09%         41,09%         $37,83 B
